# %% [markdown]
# <a href="https://colab.research.google.com/github/ENV716/Energy_Modeling_F2022/blob/main/Lab/Lab09/Lab09_MultiPeriodLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 9 - Multi-period LPs in Python**

# %% [markdown]
# Learning outcomes for Lab 9:
# * Learn how to implement multi-period LPs;
# * Show how to handle ordered sets.

# %% [markdown]
# ## Initializing

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Installing Pyomo and glpk solver.

# %%
# !pip install pyomo
# !apt-get install -y -qq glpk-utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyomo
#   Downloading Pyomo-6.4.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 3.7 MB/s
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.6 MB/s
# Installing collected packages: ply, pyomo
# Successfully installed ply-3.11 pyomo-6.4.2
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# (Reading database ... 123942 files and directories currently installed.)
# Preparing to unpack .../libsuitesparseconfig5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../libamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../libcolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libglpk40:amd64.
# Preparing to unpack .../libglpk40_4.65-1_amd64.deb ...
# Unpacking libglpk40:amd64 (4.65-1) ...
# Selecting previously unselected package glpk-utils.
# Preparing to unpack .../glpk-utils_4.65-1_amd64.deb ...
# Unpacking glpk-utils (4.65-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Setting up libcolamd2:amd64 (1:5.1.2-2) ...
# Setting up libamd2:amd64 (1:5.1.2-2) ...
# Setting up libglpk40:amd64 (4.65-1) ...
# Setting up glpk-utils (4.65-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# Importing pyomo and solver.

# %%
from pyomo.environ import *
#Import solver
opt=SolverFactory('glpk')

# %% [markdown]
# ## Multiperiod LP

# %% [markdown]
# Recall the example from lecture 16. A new company will manufacture 3 products by processing them in 2 different machines.
#
# Each product can be produced either
# inside the company or outside, at a higher cost.
# The inside production is constrained by the hours available at each machine, while outside production is unlimited.
#
# The company has sales contracts for the next 4 weeks.
#
# Production that exceeds the sales contracts can be kept in inventories at a cost.
#
# Find the optimal **production/purchase/inventory strategy**.

# %% [markdown]
# ![Screen Shot 2021-10-14 at 10.19.11 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-10-14 at 10.18.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Defining model, sets, parameters and decision variables

# %%
#using sets and parameter
model=ConcreteModel()

#Sets M,P,T
##YOUR CODE##

#Parameters
##YOUR CODE##

#add dec variables
##YOUR CODE##

# %% [markdown]
# ### Defining objective function
#
# Remember we want to minimize production cost.

# %%
#add obj func
##YOUR CODE##

#Checking objetive function
print(##YOUR CODE##)

# %% [markdown]
# ### Adding model constrains

# %%
#add machine availability const
##YOUR CODE##

#Checking added constraints
for m in model.M:
  for t in model.T:
    print(##YOUR CODE##)

# %%
##YOUR CODE##

#Checking added constraints
for p in model.P:
  for t in model.T:
    print(##YOUR CODE##)

# %% [markdown]
# ### Solving the model and reporting results

# %%
#Solve model
opt.solve(model)

#Print results
print("Cost =",model.cost())
print("Decision Variables")
for p in model.P:
  for t in model.T:
    ##YOUR CODE##
